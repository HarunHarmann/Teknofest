# %%
import torch

print(torch.cuda.is_available())


print(torch.cuda.device_count())


print(torch.cuda.current_device())


print(torch.cuda.device(0))


print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# 0
# ...
# NVIDIA GeForce RTX 2060

# %%
# !nvidia-smi
# Out:
# Thu Jun 20 20:39:34 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.23                 Driver Version: 536.23       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 2060      WDDM  | 00000000:09:00.0  On |                  N/A |
# |  0%   51C    P0              37W / 170W |    506MiB /  6144MiB |      1%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import torch

# Check if torch is installed and print the version
try:
    print(f"Torch version: {torch.__version__}")
    if torch.cuda.is_available():
        print(f"CUDA is available. CUDA version: {torch.version.cuda}")
    else:
        print("CUDA is not available.")
except ImportError:
    print("Torch is not installed.")
# Out:
# Torch version: 2.3.1
# CUDA is available. CUDA version: 12.1

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5.git

# Change directory to yolov5
# %cd yolov5

# Install YOLOv5 dependencies
# !pip install -r requirements.txt
# Out:
# C:\Users\YiğitYıldırım\Desktop\YoloCudaJupyter\yolov5
# Cloning into 'yolov5'...
# D:\anaconda3\envs\pytorch_env_new\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# ...
#      ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/41.2 kB 682.7 kB/s eta 0:00:01
#      -------------------------------------- 41.2/41.2 kB 673.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/207.3 kB ? eta -:--:--
#    ----------------------------- ---------- 153.6/207.3 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 207.3/207.3 kB 3.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/782.8 kB ? eta -:--:--
#    ------------------------ -------------- 501.8/782.8 kB 30.7 MB/s eta 0:00:01
# ...

# %%
import os
import torch

# Ensure you're in the yolov5 directory
# %cd C:\Users\YiğitYıldırım\Desktop\YoloCudaJupyter\yolov5
# Out:
# C:\Users\YiğitYıldırım\Desktop\YoloCudaJupyter\yolov5

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1C61-3092
#
#  Directory of C:\Users\Yi§itY�ld�r�m\Desktop\YoloCudaJupyter\yolov5
#
# 19.06.2024  14:23    <DIR>          .
# 19.06.2024  14:23    <DIR>          ..
# 19.06.2024  14:23             3.923 .dockerignore
# 19.06.2024  14:23                77 .gitattributes
# 19.06.2024  14:23    <DIR>          .github
# 19.06.2024  14:23             4.255 .gitignore
# 19.06.2024  14:23             8.237 benchmarks.py
# 19.06.2024  14:23               407 CITATION.cff
# 19.06.2024  14:23    <DIR>          classify
# 19.06.2024  14:23             5.074 CONTRIBUTING.md
# 19.06.2024  14:28    <DIR>          data
# 19.06.2024  14:23            16.499 detect.py
# 19.06.2024  14:23            43.485 export.py
# 19.06.2024  14:23             8.964 hubconf.py
# 19.06.2024  14:23            35.184 LICENSE
# 19.06.2024  14:23    <DIR>          models
# 19.06.2024  14:23             5.525 pyproject.toml
# ...

# %%
# !pip install GPUtil
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7400 sha256=3ea575610345373fb9ce5c50e806ea6bab121144480b71bcf5bf32ed235b687f
#   Stored in directory: c:\users\yiğityıldırım\appdata\local\pip\cache\wheels\92\a8\b7\d8a067c31a74de9ca252bbe53dea5f896faabd25d55f541037
# Successfully built GPUtil
# ...

# %%
from GPUtil import showUtilization as gpu_usage
gpu_usage()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 85% |

# %%
# !pip install numba
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.7 MB 991.0 kB/s eta 0:00:03
#    ------ --------------------------------- 0.5/2.7 MB 4.0 MB/s eta 0:00:01
#    -------------------- ------------------- 1.4/2.7 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 15.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 13.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    ---- ----------------------------------- 3.1/28.1 MB 66.7 MB/s eta 0:00:01
#    ---- ----------------------------------- 3.3/28.1 MB 69.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 4.1/28.1 MB 33.1 MB/s eta 0:00:01
#    ------- -------------------------------- 5.1/28.1 MB 29.5 MB/s eta 0:00:01
# ...

# %%
import torch
from GPUtil import showUtilization as gpu_usage
from numba import cuda

def free_gpu_cache():
    print("Initial GPU Usage")
    gpu_usage()                             

    torch.cuda.empty_cache()

    cuda.select_device(0)
    cuda.close()
    cuda.select_device(0)

    print("GPU Usage after emptying the cache")
    gpu_usage()

free_gpu_cache()
# Out:
# Initial GPU Usage
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 28% |

# %%
import torch

print(torch.cuda.is_available())


print(torch.cuda.device_count())


print(torch.cuda.current_device())


print(torch.cuda.device(0))


print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# 0
# ...
# NVIDIA GeForce RTX 2060
# CUDA available: True
# CUDA version: 12.1

# %%
# !nvidia-smi
# Out:
# Thu Jun 20 20:18:22 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.23                 Driver Version: 536.23       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 2060      WDDM  | 00000000:09:00.0  On |                  N/A |
# |  0%   50C    P8              20W / 170W |   5462MiB /  6144MiB |      4%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import torch 
torch.cuda.empty_cache()

# %%
from yolov5 import train
# Define training parameters
img_size = 1280
batch_size = -1
epochs = 15
data_config = 'C:\\Users\\YiğitYıldırım\\Desktop\\YoloCudaJupyter\\yolov5\\data\\dataset_v5.yaml'
weights = 'yolov5n.pt'

# Train the model
train.run(imgsz=img_size, batch_size=batch_size, epochs=epochs, data=data_config, weights=weights)
# Out:
# train: weights=yolov5n.pt, cfg=, data=C:\Users\YiitYldrm\Desktop\YoloCudaJupyter\yolov5\data\dataset_v5.yaml, hyp=yolov5\data\hyps\hyp.scratch-low.yaml, epochs=15, batch_size=-1, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5\data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5\runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github:  YOLOv5 is out of date by 3 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5  v7.0-326-gec331cbd Python-3.12.3 torch-2.3.1 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
#
# ...
